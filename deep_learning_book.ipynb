# %% [markdown]
# Chapter 7

# %%
from tensorflow.keras import Input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
# Out:
# /Users/kamruzzamankhanalve/Documents/4-2 semester/CSE 4203 Machine Learning/CSE 4204/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
from tensorflow.keras import Input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import numpy as np

seed = 7
np.random.seed(seed)

# %%
# load pima indians dataset
dataset = np.loadtxt(
    "pima-indians-diabetes_original.csv",
    delimiter=",",
    skiprows=1,
)
# split into input (X) and output (Y) variables
X = dataset[:, 0:8]
Y = dataset[:, 8]

#create model
model = Sequential()
model.add(Input(shape=(8,)))
model.add(Dense(12, kernel_initializer='uniform', activation='relu'))
model.add(Dense(8, kernel_initializer='uniform', activation='relu'))
model.add(Dense(1, kernel_initializer='uniform', activation='sigmoid'))

#compile model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

#fit the model
model.fit(X, Y, epochs=50, batch_size=10)

#evaluate the model
scores = model.evaluate(X, Y, verbose=0, return_dict=True)
print(f"accuracy: {scores['accuracy'] * 100:.2f}%")
# Out:
# Epoch 1/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 527us/step - accuracy: 0.5965 - loss: 0.6839
# Epoch 2/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 407us/step - accuracy: 0.6596 - loss: 0.6643
# Epoch 3/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step - accuracy: 0.6582 - loss: 0.6579
# Epoch 4/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 389us/step - accuracy: 0.6137 - loss: 0.6715
# Epoch 5/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 369us/step - accuracy: 0.6604 - loss: 0.6358
# Epoch 6/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 433us/step - accuracy: 0.6682 - loss: 0.6290
# Epoch 7/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 390us/step - accuracy: 0.6994 - loss: 0.5831
# Epoch 8/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 358us/step - accuracy: 0.6979 - loss: 0.5889
# Epoch 9/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 368us/step - accuracy: 0.6727 - loss: 0.6091
# Epoch 10/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 417us/step - accuracy: 0.7082 - loss: 0.5943
# Epoch 11/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 404us/step - accuracy: 0.7173 - loss: 0.5729
# ...

# %% [markdown]
# CHAPTER 8

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# [Fact] Set both Numpy and TF seeds for strict reproducibility
seed = 7
np.random.seed(seed)
tf.random.set_seed(seed)

# Load dataset
dataset = np.loadtxt(
    "pima-indians-diabetes_original.csv",
    delimiter=",",
    skiprows=1,
)

# Split into input (X) and output (Y) variables
X = dataset[:, 0:8]
Y = dataset[:, 8]

# [Style] Passing layers as a list is cleaner than sequential .add() calls
model = Sequential([
    Dense(12, input_dim=8, kernel_initializer='uniform', activation='relu'),
    Dense(8, kernel_initializer='uniform', activation='relu'),
    Dense(1, kernel_initializer='uniform', activation='sigmoid')
])

# Compile model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Fit the model
# [Fact] Updated kwargs: nb_epoch -> epochs
model.fit(X, Y, validation_split=0.33, epochs=150, batch_size=10)
# Out:
# Epoch 1/150
# /Users/kamruzzamankhanalve/Documents/4-2 semester/CSE 4203 Machine Learning/CSE 4204/.venv/lib/python3.9/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6535 - loss: 0.6918 - val_accuracy: 0.6811 - val_loss: 0.6863
# Epoch 2/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 791us/step - accuracy: 0.6349 - loss: 0.6866 - val_accuracy: 0.6732 - val_loss: 0.6805
# Epoch 3/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 678us/step - accuracy: 0.6327 - loss: 0.6821 - val_accuracy: 0.6732 - val_loss: 0.6752
# Epoch 4/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 674us/step - accuracy: 0.6336 - loss: 0.6780 - val_accuracy: 0.6772 - val_loss: 0.6706
# Epoch 5/150
# ...

# %%
# MLP for Pima Indians Dataset with 10-fold cross validation
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import StratifiedKFold
import numpy as np

# Load dataset
dataset = np.loadtxt(
    "pima-indians-diabetes_original.csv",
    delimiter=",",
    skiprows=1,
)

# Split into input (X) and output (Y) variables
X = dataset[:, 0:8]
Y = dataset[:, 8]


kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=seed)
cvscores = []
for train, test in kfold.split(X, Y):
    # create model
    model = Sequential()
    model.add(Input(shape=(8,)))
    model.add(Dense(12, kernel_initializer='uniform', activation='relu'))
    model.add(Dense(8, kernel_initializer='uniform', activation='relu'))
    model.add(Dense(1, kernel_initializer='uniform', activation='sigmoid'))
    # Compile model
    model.compile(loss= "binary_crossentropy" , optimizer= "adam" , metrics=["accuracy"])
    #fit the model
    model.fit(X, Y, epochs=50, batch_size=10)
    # evaluate the model
    scores = model.evaluate(X[test], Y[test], verbose=0)
    print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
    cvscores.append(scores[1] * 100)

print("%.2f%% (+/- %.2f%%)" % (np.mean(cvscores), np.std(cvscores)))
# Out:
# Epoch 1/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 557us/step - accuracy: 0.6467 - loss: 0.6785
# Epoch 2/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 450us/step - accuracy: 0.6467 - loss: 0.6654
# Epoch 3/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 356us/step - accuracy: 0.6467 - loss: 0.6593
# Epoch 4/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 357us/step - accuracy: 0.6447 - loss: 0.6541
# Epoch 5/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 362us/step - accuracy: 0.6470 - loss: 0.6489
# Epoch 6/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 346us/step - accuracy: 0.6561 - loss: 0.6434
# Epoch 7/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 357us/step - accuracy: 0.6617 - loss: 0.6375
# Epoch 8/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 398us/step - accuracy: 0.6651 - loss: 0.6318
# Epoch 9/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step - accuracy: 0.6671 - loss: 0.6252
# Epoch 10/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 364us/step - accuracy: 0.7115 - loss: 0.6195
# Epoch 11/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 357us/step - accuracy: 0.7217 - loss: 0.6145
# ...

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import StratifiedKFold

seed = 7
np.random.seed(seed)
tf.random.set_seed(seed)

def create_model():
    model = Sequential([
        Input(shape=(8,)),
        Dense(12, kernel_initializer='uniform', activation='relu'),
        Dense(8, kernel_initializer='uniform', activation='relu'),
        Dense(1, kernel_initializer='uniform', activation='sigmoid')
    ])
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

dataset = np.loadtxt(
    "pima-indians-diabetes_original.csv",
    delimiter=",",
    skiprows=1,
)
X = dataset[:, 0:8]
Y = dataset[:, 8]

kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=seed)
cvscores = []

for fold, (train_idx, test_idx) in enumerate(kfold.split(X, Y), start=1):
    model = create_model()
    model.fit(X[train_idx], Y[train_idx], epochs=150, batch_size=10, verbose=0)
    scores = model.evaluate(X[test_idx], Y[test_idx], verbose=0, return_dict=True)
    accuracy = scores['accuracy'] * 100
    print(f"Fold {fold} accuracy: {accuracy:.2f}%")
    cvscores.append(accuracy)

print(f"Mean Accuracy: {np.mean(cvscores):.2f}% (+/- {np.std(cvscores):.2f}%)")
# Out:
# Fold 1 accuracy: 75.32%
# Fold 2 accuracy: 81.82%
# Fold 3 accuracy: 70.13%
# Fold 4 accuracy: 83.12%
# Fold 5 accuracy: 70.13%
# Fold 6 accuracy: 68.83%
# Fold 7 accuracy: 80.52%
# Fold 8 accuracy: 77.92%
# Fold 9 accuracy: 76.32%
# Fold 10 accuracy: 80.26%
# Mean Accuracy: 76.44% (+/- 4.96%)

# %% [markdown]
# CHAPTER 8

# %%
from keras.models import Sequential
from keras.layers import Dense, Input
import numpy
# fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)
# load pima indians dataset
dataset = numpy.loadtxt("pima-indians-diabetes_original.csv", delimiter=",", skiprows=1)
# split into input (X) and output (Y) variables
X = dataset[:,0:8]
Y = dataset[:,8]
# create model
model = Sequential()
model.add(Input(shape=(8,)))
model.add(Dense(12, kernel_initializer='uniform', activation='relu'))
model.add(Dense(8, kernel_initializer='uniform', activation='relu'))
model.add(Dense(1, kernel_initializer='uniform', activation='sigmoid'))
# Compile model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# Fit the model
model.fit(X, Y, validation_split=0.33, epochs=150, batch_size=10)
# Out:
# Epoch 1/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5639 - loss: 0.6889 - val_accuracy: 0.6732 - val_loss: 0.6651
# Epoch 2/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 925us/step - accuracy: 0.6348 - loss: 0.6712 - val_accuracy: 0.6732 - val_loss: 0.6536
# Epoch 3/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step - accuracy: 0.6331 - loss: 0.6614 - val_accuracy: 0.6850 - val_loss: 0.6480
# Epoch 4/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 779us/step - accuracy: 0.6451 - loss: 0.6531 - val_accuracy: 0.6732 - val_loss: 0.6426
# Epoch 5/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 765us/step - accuracy: 0.6454 - loss: 0.6452 - val_accuracy: 0.6654 - val_loss: 0.6361
# Epoch 6/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 771us/step - accuracy: 0.6417 - loss: 0.6370 - val_accuracy: 0.6693 - val_loss: 0.6268
# Epoch 7/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step - accuracy: 0.6415 - loss: 0.6290 - val_accuracy: 0.6772 - val_loss: 0.6188
# Epoch 8/150
# ...

# %%
# MLP with manual validation set
from keras.models import Sequential
from keras.layers import Dense, Input
from sklearn.model_selection import train_test_split
import numpy
# fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)
# load pima indians dataset
dataset = numpy.loadtxt("pima-indians-diabetes_original.csv", delimiter=",", skiprows=1)
# split into input (X) and output (Y) variables
X = dataset[:,0:8]
Y = dataset[:,8]
# split into 67% for train and 33% for test
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.33, random_state=seed)
# create model
model = Sequential()
model.add(Input(shape=(8,)))
model.add(Dense(12, kernel_initializer='uniform', activation='relu'))
model.add(Dense(8, kernel_initializer='uniform', activation='relu'))
model.add(Dense(1, kernel_initializer='uniform', activation='sigmoid'))
# Compile model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# Fit the model
model.fit(X_train, y_train, validation_data=(X_test,y_test), epochs=150, batch_size=10)
# Out:
# Epoch 1/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6556 - loss: 0.6828 - val_accuracy: 0.6378 - val_loss: 0.6743
# Epoch 2/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 967us/step - accuracy: 0.6556 - loss: 0.6652 - val_accuracy: 0.6378 - val_loss: 0.6681
# Epoch 3/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step - accuracy: 0.6556 - loss: 0.6607 - val_accuracy: 0.6378 - val_loss: 0.6642
# Epoch 4/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 881us/step - accuracy: 0.6556 - loss: 0.6570 - val_accuracy: 0.6378 - val_loss: 0.6601
# Epoch 5/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 880us/step - accuracy: 0.6556 - loss: 0.6533 - val_accuracy: 0.6378 - val_loss: 0.6555
# Epoch 6/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 862us/step - accuracy: 0.6556 - loss: 0.6489 - val_accuracy: 0.6378 - val_loss: 0.6497
# Epoch 7/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 839us/step - accuracy: 0.6556 - loss: 0.6433 - val_accuracy: 0.6378 - val_loss: 0.6422
# Epoch 8/150
# ...

# %%
# MLP for Pima Indians Dataset with 10-fold cross validation via sklearn
from tensorflow.keras import Input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from scikeras.wrappers import KerasClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
import numpy as np
import pandas as pd

seed = 7
np.random.seed(seed)

# load pima indians dataset using pandas
dataframe = pd.read_csv("pima-indians-diabetes_original.csv")
dataset = dataframe.values
# split into input (X) and output (Y) variables
X = dataset[:, 0:8]
Y = dataset[:, 8]

# define 10-fold cross validation
kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=seed)
cvscores = []

for fold, (train_idx, test_idx) in enumerate(kfold.split(X, Y), start=1):
    # create model
    model = Sequential()
    model.add(Input(shape=(8,)))
    model.add(Dense(12, kernel_initializer='uniform', activation='relu'))
    model.add(Dense(8, kernel_initializer='uniform', activation='relu'))
    model.add(Dense(1, kernel_initializer='uniform', activation='sigmoid'))
    # Compile model
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    # Fit the model
    model.fit(X[train_idx], Y[train_idx], epochs=150, batch_size=10, verbose=0)
    # evaluate the model
    scores = model.evaluate(X[test_idx], Y[test_idx], verbose=0, return_dict=True)
    accuracy = scores['accuracy'] * 100
    print(f"Fold {fold} accuracy: {accuracy:.2f}%")
    cvscores.append(accuracy)

print(f"Mean Accuracy: {np.mean(cvscores):.2f}% (+/- {np.std(cvscores):.2f}%)")
# Out:
# Fold 1 accuracy: 81.82%
# Fold 2 accuracy: 75.32%
# Fold 3 accuracy: 79.22%
# Fold 4 accuracy: 80.52%
# Fold 5 accuracy: 70.13%
# Fold 6 accuracy: 64.94%
# Fold 7 accuracy: 79.22%
# Fold 8 accuracy: 75.32%
# Fold 9 accuracy: 72.37%
# Fold 10 accuracy: 81.58%
# Mean Accuracy: 76.04% (+/- 5.26%)

# %% [markdown]
# CHAPTER 9

# %%
# MLP for Pima Indians Dataset with 10-fold cross validation via sklearn
from keras.layers import Dense
from keras.models import Sequential
from keras import Input
from sklearn.model_selection import StratifiedKFold
import numpy as np
import pandas as pd

def create_model():
    model = Sequential()
    model.add(Input(shape=(8,)))
    model.add(Dense(12, kernel_initializer='uniform', activation='relu'))
    model.add(Dense(8, kernel_initializer='uniform', activation='relu'))
    model.add(Dense(1, kernel_initializer='uniform', activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

seed = 7
np.random.seed(seed)

dataframe = pd.read_csv('pima-indians-diabetes_original.csv')
dataset = dataframe.values

# split into input (X) and output (Y) variables
X = dataset[:, 0:8]
Y = dataset[:, 8]

# evaluate using 10-fold cross validation
kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=seed)
cvscores = []

for fold, (train_idx, test_idx) in enumerate(kfold.split(X, Y), start=1):
    model = create_model()
    model.fit(X[train_idx], Y[train_idx], epochs=150, batch_size=10, verbose=0)
    scores = model.evaluate(X[test_idx], Y[test_idx], verbose=0, return_dict=True)
    accuracy = scores['accuracy'] * 100
    print(f'Fold {fold} accuracy: {accuracy:.2f}%')
    cvscores.append(accuracy)

print(f'Mean Accuracy: {np.mean(cvscores):.2f}% (+/- {np.std(cvscores):.2f}%)')
# Out:
# Fold 1 accuracy: 74.03%
# Fold 2 accuracy: 79.22%
# Fold 3 accuracy: 77.92%
# Fold 4 accuracy: 77.92%
# Fold 5 accuracy: 66.23%
# Fold 6 accuracy: 64.94%
# Fold 7 accuracy: 79.22%
# Fold 8 accuracy: 72.73%
# Fold 9 accuracy: 76.32%
# Fold 10 accuracy: 82.89%
# Mean Accuracy: 75.14% (+/- 5.48%)

# %%
# MLP for Pima Indians Dataset with grid search via sklearn
from keras.models import Sequential
from keras.layers import Dense
from keras import Input
from scikeras.wrappers import KerasClassifier
from sklearn.model_selection import GridSearchCV
import numpy as np
import pandas as pd

# Fix scikeras 0.13 + sklearn 1.6 compatibility
import scikeras.wrappers as _sw
from sklearn.base import BaseEstimator
_sw.BaseWrapper.__sklearn_tags__ = lambda self: BaseEstimator.__sklearn_tags__(self)

def create_model(optimizer='adam', init='glorot_uniform'):
    model = Sequential()
    model.add(Input(shape=(8,)))
    model.add(Dense(12, kernel_initializer=init, activation='relu'))
    model.add(Dense(8, kernel_initializer=init, activation='relu'))
    model.add(Dense(1, kernel_initializer=init, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    return model

seed = 7
np.random.seed(seed)

dataframe = pd.read_csv('pima-indians-diabetes_original.csv')
dataset = dataframe.values

# split into input (X) and output (Y) variables
X = dataset[:, 0:8]
Y = dataset[:, 8]

model = KerasClassifier(model=create_model, epochs=150, batch_size=10, verbose=0)
# define the grid search parameters
optimizers = ['rmsprop', 'adam']
param_grid = dict(optimizer=optimizers)
grid = GridSearchCV(estimator=model, param_grid=param_grid, cv=3)
grid_result = grid.fit(X, Y)

# summarize results
print(f'Best: {grid_result.best_score_:.4f} using {grid_result.best_params_}')
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print(f'{mean:.4f} (+/-{stdev:.4f}) with: {param}')
# Out:
# Best: 0.7135 using {'optimizer': 'adam'}
# 0.6914 (+/-0.0032) with: {'optimizer': 'rmsprop'}
# 0.7135 (+/-0.0192) with: {'optimizer': 'adam'}
